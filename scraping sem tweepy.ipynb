# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from time import sleep
import json
import datetime

# edit these three variables
user = 'galhardothami'
start = datetime.datetime(2015, 4, 1)  # year, month, day
end = datetime.datetime(2019, 2, 25)  # year, month, day

# only edit these if you're having problems
delay = 1  # time to wait on each page load before reading the page
driver = webdriver.Chrome()  # options are Chrome() Firefox() Safari()

# don't mess with this stuff
twitter_ids_filename = 'all_ids.json'
days = (end - start).days + 1
id_selector = '.time a.tweet-timestamp'
tweet_selector = 'li.js-stream-item'
user = user.lower()
ids = []

def format_day(date):
    day = '0' + str(date.day) if len(str(date.day)) == 1 else str(date.day)
    month = '0' + str(date.month) if len(str(date.month)) == 1 else str(date.month)
    year = str(date.year)
    return '-'.join([year, month, day])

def form_url(since, until):
    p1 = 'https://twitter.com/search?f=tweets&vertical=default&q=from%3A'
    p2 =  user + '%20since%3A' + since + '%20until%3A' + until + 'include%3Aretweets&src=typd'
    return p1 + p2

def increment_day(date, i):
    return date + datetime.timedelta(days=i)

for day in range(days):
    d1 = format_day(increment_day(start, 0))
    d2 = format_day(increment_day(start, 1))
    url = form_url(d1, d2)
    print(url)
    print(d1)
    driver.get(url)
    sleep(delay)

    try:
        found_tweets = driver.find_elements_by_css_selector(tweet_selector)
        increment = 10

        while len(found_tweets) >= increment:
            print('scrolling down to load more tweets')
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            sleep(delay)
            found_tweets = driver.find_elements_by_css_selector(tweet_selector)
            increment += 10

        print('{} tweets found, {} total'.format(len(found_tweets), len(ids)))

        for tweet in found_tweets:
            try:
                id = tweet.find_element_by_css_selector(id_selector).get_attribute('href').split('/')[-1]
                ids.append(id)
            except StaleElementReferenceException as e:
                print('lost element reference', tweet)

    except NoSuchElementException:
        print('no tweets on this day')

    start = increment_day(start, 1)

try:
    with open(twitter_ids_filename) as f:
        all_ids = ids + json.load(f)
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))

except FileNotFoundError:
    with open(twitter_ids_filename, 'w') as f:
        all_ids = ids
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))

with open(twitter_ids_filename, 'w') as outfile:
    json.dump(data_to_write, outfile)

print('all done here')
driver.close()
# Out:
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-01%20until%3A2015-04-02include%3Aretweets&src=typd
# 2015-04-01
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-02%20until%3A2015-04-03include%3Aretweets&src=typd
# 2015-04-02
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-03%20until%3A2015-04-04include%3Aretweets&src=typd
# 2015-04-03
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-04%20until%3A2015-04-05include%3Aretweets&src=typd
# 2015-04-04
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-05%20until%3A2015-04-06include%3Aretweets&src=typd
# 2015-04-05
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-06%20until%3A2015-04-07include%3Aretweets&src=typd
# 2015-04-06
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-07%20until%3A2015-04-08include%3Aretweets&src=typd
# 2015-04-07
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-08%20until%3A2015-04-09include%3Aretweets&src=typd
# 2015-04-08
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-09%20until%3A2015-04-10include%3Aretweets&src=typd
# 2015-04-09
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-10%20until%3A2015-04-11include%3Aretweets&src=typd
# 2015-04-10
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-11%20until%3A2015-04-12include%3Aretweets&src=typd
# 2015-04-11
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-12%20until%3A2015-04-13include%3Aretweets&src=typd
# 2015-04-12
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-13%20until%3A2015-04-14include%3Aretweets&src=typd
# 2015-04-13
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-14%20until%3A2015-04-15include%3Aretweets&src=typd
# 2015-04-14
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-15%20until%3A2015-04-16include%3Aretweets&src=typd
# 2015-04-15
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-16%20until%3A2015-04-17include%3Aretweets&src=typd
# 2015-04-16
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-17%20until%3A2015-04-18include%3Aretweets&src=typd
# 2015-04-17
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-18%20until%3A2015-04-19include%3Aretweets&src=typd
# 2015-04-18
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-19%20until%3A2015-04-20include%3Aretweets&src=typd
# 2015-04-19
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-20%20until%3A2015-04-21include%3Aretweets&src=typd
# 2015-04-20
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-21%20until%3A2015-04-22include%3Aretweets&src=typd
# 2015-04-21
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-22%20until%3A2015-04-23include%3Aretweets&src=typd
# 2015-04-22
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-23%20until%3A2015-04-24include%3Aretweets&src=typd
# 2015-04-23
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-24%20until%3A2015-04-25include%3Aretweets&src=typd
# 2015-04-24
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-25%20until%3A2015-04-26include%3Aretweets&src=typd
# 2015-04-25
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-26%20until%3A2015-04-27include%3Aretweets&src=typd
# 2015-04-26
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-27%20until%3A2015-04-28include%3Aretweets&src=typd
# 2015-04-27
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-28%20until%3A2015-04-29include%3Aretweets&src=typd
# 2015-04-28
# 5 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-29%20until%3A2015-04-30include%3Aretweets&src=typd
# 2015-04-29
# scrolling down to load more tweets
# 13 tweets found, 5 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-04-30%20until%3A2015-05-01include%3Aretweets&src=typd
# 2015-04-30
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 36 tweets found, 18 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-01%20until%3A2015-05-02include%3Aretweets&src=typd
# 2015-05-01
# 6 tweets found, 54 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-02%20until%3A2015-05-03include%3Aretweets&src=typd
# 2015-05-02
# scrolling down to load more tweets
# 18 tweets found, 60 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-03%20until%3A2015-05-04include%3Aretweets&src=typd
# 2015-05-03
# scrolling down to load more tweets
# scrolling down to load more tweets
# 29 tweets found, 78 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-04%20until%3A2015-05-05include%3Aretweets&src=typd
# 2015-05-04
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 61 tweets found, 107 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-05%20until%3A2015-05-06include%3Aretweets&src=typd
# 2015-05-05
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 34 tweets found, 168 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-06%20until%3A2015-05-07include%3Aretweets&src=typd
# 2015-05-06
# scrolling down to load more tweets
# 17 tweets found, 202 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-07%20until%3A2015-05-08include%3Aretweets&src=typd
# 2015-05-07
# scrolling down to load more tweets
# 17 tweets found, 219 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-08%20until%3A2015-05-09include%3Aretweets&src=typd
# 2015-05-08
# scrolling down to load more tweets
# 13 tweets found, 236 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-09%20until%3A2015-05-10include%3Aretweets&src=typd
# 2015-05-09
# scrolling down to load more tweets
# 13 tweets found, 249 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-10%20until%3A2015-05-11include%3Aretweets&src=typd
# 2015-05-10
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 30 tweets found, 262 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-11%20until%3A2015-05-12include%3Aretweets&src=typd
# 2015-05-11
# scrolling down to load more tweets
# scrolling down to load more tweets
# 24 tweets found, 292 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-12%20until%3A2015-05-13include%3Aretweets&src=typd
# 2015-05-12
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 43 tweets found, 316 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-13%20until%3A2015-05-14include%3Aretweets&src=typd
# 2015-05-13
# scrolling down to load more tweets
# 16 tweets found, 359 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-14%20until%3A2015-05-15include%3Aretweets&src=typd
# 2015-05-14
# 9 tweets found, 375 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-15%20until%3A2015-05-16include%3Aretweets&src=typd
# 2015-05-15
# scrolling down to load more tweets
# scrolling down to load more tweets
# 23 tweets found, 384 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-16%20until%3A2015-05-17include%3Aretweets&src=typd
# 2015-05-16
# 5 tweets found, 407 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-17%20until%3A2015-05-18include%3Aretweets&src=typd
# 2015-05-17
# scrolling down to load more tweets
# 11 tweets found, 412 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-18%20until%3A2015-05-19include%3Aretweets&src=typd
# 2015-05-18
# scrolling down to load more tweets
# scrolling down to load more tweets
# 21 tweets found, 423 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-19%20until%3A2015-05-20include%3Aretweets&src=typd
# 2015-05-19
# scrolling down to load more tweets
# 17 tweets found, 444 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-20%20until%3A2015-05-21include%3Aretweets&src=typd
# 2015-05-20
# 9 tweets found, 461 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-21%20until%3A2015-05-22include%3Aretweets&src=typd
# 2015-05-21
# 8 tweets found, 470 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-22%20until%3A2015-05-23include%3Aretweets&src=typd
# 2015-05-22
# 8 tweets found, 478 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-23%20until%3A2015-05-24include%3Aretweets&src=typd
# 2015-05-23
# scrolling down to load more tweets
# 11 tweets found, 486 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-24%20until%3A2015-05-25include%3Aretweets&src=typd
# 2015-05-24
# scrolling down to load more tweets
# 10 tweets found, 497 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-25%20until%3A2015-05-26include%3Aretweets&src=typd
# 2015-05-25
# scrolling down to load more tweets
# 19 tweets found, 507 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-26%20until%3A2015-05-27include%3Aretweets&src=typd
# 2015-05-26
# 8 tweets found, 526 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-27%20until%3A2015-05-28include%3Aretweets&src=typd
# 2015-05-27
# 7 tweets found, 534 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-28%20until%3A2015-05-29include%3Aretweets&src=typd
# 2015-05-28
# 7 tweets found, 541 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-29%20until%3A2015-05-30include%3Aretweets&src=typd
# 2015-05-29
# 7 tweets found, 548 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-30%20until%3A2015-05-31include%3Aretweets&src=typd
# 2015-05-30
# scrolling down to load more tweets
# 12 tweets found, 555 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-05-31%20until%3A2015-06-01include%3Aretweets&src=typd
# 2015-05-31
# 7 tweets found, 567 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-01%20until%3A2015-06-02include%3Aretweets&src=typd
# 2015-06-01
# scrolling down to load more tweets
# 12 tweets found, 574 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-02%20until%3A2015-06-03include%3Aretweets&src=typd
# 2015-06-02
# 8 tweets found, 586 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-03%20until%3A2015-06-04include%3Aretweets&src=typd
# 2015-06-03
# 1 tweets found, 594 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-04%20until%3A2015-06-05include%3Aretweets&src=typd
# 2015-06-04
# 8 tweets found, 595 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-05%20until%3A2015-06-06include%3Aretweets&src=typd
# 2015-06-05
# 8 tweets found, 603 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-06%20until%3A2015-06-07include%3Aretweets&src=typd
# 2015-06-06
# scrolling down to load more tweets
# 14 tweets found, 611 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-07%20until%3A2015-06-08include%3Aretweets&src=typd
# 2015-06-07
# scrolling down to load more tweets
# 11 tweets found, 625 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-08%20until%3A2015-06-09include%3Aretweets&src=typd
# 2015-06-08
# scrolling down to load more tweets
# 12 tweets found, 636 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-09%20until%3A2015-06-10include%3Aretweets&src=typd
# 2015-06-09
# 3 tweets found, 648 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-10%20until%3A2015-06-11include%3Aretweets&src=typd
# 2015-06-10
# 1 tweets found, 651 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-11%20until%3A2015-06-12include%3Aretweets&src=typd
# 2015-06-11
# 6 tweets found, 652 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-12%20until%3A2015-06-13include%3Aretweets&src=typd
# 2015-06-12
# 4 tweets found, 658 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-13%20until%3A2015-06-14include%3Aretweets&src=typd
# 2015-06-13
# 5 tweets found, 662 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-14%20until%3A2015-06-15include%3Aretweets&src=typd
# 2015-06-14
# 5 tweets found, 667 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-15%20until%3A2015-06-16include%3Aretweets&src=typd
# 2015-06-15
# 0 tweets found, 672 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-16%20until%3A2015-06-17include%3Aretweets&src=typd
# 2015-06-16
# 2 tweets found, 672 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-17%20until%3A2015-06-18include%3Aretweets&src=typd
# 2015-06-17
# 1 tweets found, 674 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-18%20until%3A2015-06-19include%3Aretweets&src=typd
# 2015-06-18
# scrolling down to load more tweets
# 16 tweets found, 675 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-19%20until%3A2015-06-20include%3Aretweets&src=typd
# 2015-06-19
# 0 tweets found, 691 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-20%20until%3A2015-06-21include%3Aretweets&src=typd
# 2015-06-20
# 7 tweets found, 691 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-21%20until%3A2015-06-22include%3Aretweets&src=typd
# 2015-06-21
# scrolling down to load more tweets
# 12 tweets found, 698 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-22%20until%3A2015-06-23include%3Aretweets&src=typd
# 2015-06-22
# 4 tweets found, 710 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-23%20until%3A2015-06-24include%3Aretweets&src=typd
# 2015-06-23
# 3 tweets found, 714 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-24%20until%3A2015-06-25include%3Aretweets&src=typd
# 2015-06-24
# 5 tweets found, 717 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-25%20until%3A2015-06-26include%3Aretweets&src=typd
# 2015-06-25
# 3 tweets found, 722 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-26%20until%3A2015-06-27include%3Aretweets&src=typd
# 2015-06-26
# 7 tweets found, 725 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-27%20until%3A2015-06-28include%3Aretweets&src=typd
# 2015-06-27
# 2 tweets found, 732 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-28%20until%3A2015-06-29include%3Aretweets&src=typd
# 2015-06-28
# 6 tweets found, 734 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-29%20until%3A2015-06-30include%3Aretweets&src=typd
# 2015-06-29
# 8 tweets found, 740 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-06-30%20until%3A2015-07-01include%3Aretweets&src=typd
# 2015-06-30
# scrolling down to load more tweets
# 13 tweets found, 748 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-01%20until%3A2015-07-02include%3Aretweets&src=typd
# 2015-07-01
# scrolling down to load more tweets
# 15 tweets found, 761 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-02%20until%3A2015-07-03include%3Aretweets&src=typd
# 2015-07-02
# scrolling down to load more tweets
# 14 tweets found, 776 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-03%20until%3A2015-07-04include%3Aretweets&src=typd
# 2015-07-03
# 9 tweets found, 790 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-04%20until%3A2015-07-05include%3Aretweets&src=typd
# 2015-07-04
# 1 tweets found, 799 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-05%20until%3A2015-07-06include%3Aretweets&src=typd
# 2015-07-05
# 7 tweets found, 800 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-06%20until%3A2015-07-07include%3Aretweets&src=typd
# 2015-07-06
# scrolling down to load more tweets
# 11 tweets found, 807 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-07%20until%3A2015-07-08include%3Aretweets&src=typd
# 2015-07-07
# 1 tweets found, 818 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-08%20until%3A2015-07-09include%3Aretweets&src=typd
# 2015-07-08
# 6 tweets found, 819 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-09%20until%3A2015-07-10include%3Aretweets&src=typd
# 2015-07-09
# 3 tweets found, 825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-10%20until%3A2015-07-11include%3Aretweets&src=typd
# 2015-07-10
# 2 tweets found, 828 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-11%20until%3A2015-07-12include%3Aretweets&src=typd
# 2015-07-11
# 4 tweets found, 830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-12%20until%3A2015-07-13include%3Aretweets&src=typd
# 2015-07-12
# 2 tweets found, 834 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-13%20until%3A2015-07-14include%3Aretweets&src=typd
# 2015-07-13
# scrolling down to load more tweets
# scrolling down to load more tweets
# 22 tweets found, 836 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-14%20until%3A2015-07-15include%3Aretweets&src=typd
# 2015-07-14
# 3 tweets found, 858 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-15%20until%3A2015-07-16include%3Aretweets&src=typd
# 2015-07-15
# 2 tweets found, 861 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-16%20until%3A2015-07-17include%3Aretweets&src=typd
# 2015-07-16
# scrolling down to load more tweets
# 13 tweets found, 863 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-17%20until%3A2015-07-18include%3Aretweets&src=typd
# 2015-07-17
# scrolling down to load more tweets
# 10 tweets found, 876 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-18%20until%3A2015-07-19include%3Aretweets&src=typd
# 2015-07-18
# 7 tweets found, 886 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-19%20until%3A2015-07-20include%3Aretweets&src=typd
# 2015-07-19
# scrolling down to load more tweets
# 18 tweets found, 893 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-20%20until%3A2015-07-21include%3Aretweets&src=typd
# 2015-07-20
# 3 tweets found, 911 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-21%20until%3A2015-07-22include%3Aretweets&src=typd
# 2015-07-21
# 2 tweets found, 914 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-22%20until%3A2015-07-23include%3Aretweets&src=typd
# 2015-07-22
# 4 tweets found, 916 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-23%20until%3A2015-07-24include%3Aretweets&src=typd
# 2015-07-23
# 1 tweets found, 920 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-24%20until%3A2015-07-25include%3Aretweets&src=typd
# 2015-07-24
# 4 tweets found, 921 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-25%20until%3A2015-07-26include%3Aretweets&src=typd
# 2015-07-25
# 4 tweets found, 925 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-26%20until%3A2015-07-27include%3Aretweets&src=typd
# 2015-07-26
# 2 tweets found, 929 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-27%20until%3A2015-07-28include%3Aretweets&src=typd
# 2015-07-27
# 3 tweets found, 931 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-28%20until%3A2015-07-29include%3Aretweets&src=typd
# 2015-07-28
# 5 tweets found, 934 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-29%20until%3A2015-07-30include%3Aretweets&src=typd
# 2015-07-29
# 3 tweets found, 939 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-30%20until%3A2015-07-31include%3Aretweets&src=typd
# 2015-07-30
# 6 tweets found, 942 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-07-31%20until%3A2015-08-01include%3Aretweets&src=typd
# 2015-07-31
# 3 tweets found, 948 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-01%20until%3A2015-08-02include%3Aretweets&src=typd
# 2015-08-01
# 7 tweets found, 951 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-02%20until%3A2015-08-03include%3Aretweets&src=typd
# 2015-08-02
# 9 tweets found, 958 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-03%20until%3A2015-08-04include%3Aretweets&src=typd
# 2015-08-03
# 3 tweets found, 967 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-04%20until%3A2015-08-05include%3Aretweets&src=typd
# 2015-08-04
# 1 tweets found, 970 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-05%20until%3A2015-08-06include%3Aretweets&src=typd
# 2015-08-05
# 2 tweets found, 971 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-06%20until%3A2015-08-07include%3Aretweets&src=typd
# 2015-08-06
# 1 tweets found, 973 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-07%20until%3A2015-08-08include%3Aretweets&src=typd
# 2015-08-07
# 1 tweets found, 974 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-08%20until%3A2015-08-09include%3Aretweets&src=typd
# 2015-08-08
# 0 tweets found, 975 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-09%20until%3A2015-08-10include%3Aretweets&src=typd
# 2015-08-09
# 5 tweets found, 975 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-10%20until%3A2015-08-11include%3Aretweets&src=typd
# 2015-08-10
# 6 tweets found, 980 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-11%20until%3A2015-08-12include%3Aretweets&src=typd
# 2015-08-11
# 0 tweets found, 986 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-12%20until%3A2015-08-13include%3Aretweets&src=typd
# 2015-08-12
# 3 tweets found, 986 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-13%20until%3A2015-08-14include%3Aretweets&src=typd
# 2015-08-13
# 6 tweets found, 989 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-14%20until%3A2015-08-15include%3Aretweets&src=typd
# 2015-08-14
# 1 tweets found, 995 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-15%20until%3A2015-08-16include%3Aretweets&src=typd
# 2015-08-15
# 2 tweets found, 996 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-16%20until%3A2015-08-17include%3Aretweets&src=typd
# 2015-08-16
# 3 tweets found, 998 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-17%20until%3A2015-08-18include%3Aretweets&src=typd
# 2015-08-17
# 2 tweets found, 1001 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-18%20until%3A2015-08-19include%3Aretweets&src=typd
# 2015-08-18
# 2 tweets found, 1003 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-19%20until%3A2015-08-20include%3Aretweets&src=typd
# 2015-08-19
# 2 tweets found, 1005 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-20%20until%3A2015-08-21include%3Aretweets&src=typd
# 2015-08-20
# 3 tweets found, 1007 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-21%20until%3A2015-08-22include%3Aretweets&src=typd
# 2015-08-21
# 0 tweets found, 1010 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-22%20until%3A2015-08-23include%3Aretweets&src=typd
# 2015-08-22
# 3 tweets found, 1010 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-23%20until%3A2015-08-24include%3Aretweets&src=typd
# 2015-08-23
# 2 tweets found, 1013 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-24%20until%3A2015-08-25include%3Aretweets&src=typd
# 2015-08-24
# 3 tweets found, 1015 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-25%20until%3A2015-08-26include%3Aretweets&src=typd
# 2015-08-25
# 0 tweets found, 1018 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-26%20until%3A2015-08-27include%3Aretweets&src=typd
# 2015-08-26
# 0 tweets found, 1018 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-27%20until%3A2015-08-28include%3Aretweets&src=typd
# 2015-08-27
# 5 tweets found, 1018 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-28%20until%3A2015-08-29include%3Aretweets&src=typd
# 2015-08-28
# 5 tweets found, 1023 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-29%20until%3A2015-08-30include%3Aretweets&src=typd
# 2015-08-29
# 2 tweets found, 1028 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-30%20until%3A2015-08-31include%3Aretweets&src=typd
# 2015-08-30
# 3 tweets found, 1030 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-08-31%20until%3A2015-09-01include%3Aretweets&src=typd
# 2015-08-31
# 1 tweets found, 1033 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-01%20until%3A2015-09-02include%3Aretweets&src=typd
# 2015-09-01
# 0 tweets found, 1034 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-02%20until%3A2015-09-03include%3Aretweets&src=typd
# 2015-09-02
# 0 tweets found, 1034 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-03%20until%3A2015-09-04include%3Aretweets&src=typd
# 2015-09-03
# 0 tweets found, 1034 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-04%20until%3A2015-09-05include%3Aretweets&src=typd
# 2015-09-04
# 6 tweets found, 1034 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-05%20until%3A2015-09-06include%3Aretweets&src=typd
# 2015-09-05
# 4 tweets found, 1040 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-06%20until%3A2015-09-07include%3Aretweets&src=typd
# 2015-09-06
# 3 tweets found, 1044 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-07%20until%3A2015-09-08include%3Aretweets&src=typd
# 2015-09-07
# scrolling down to load more tweets
# 12 tweets found, 1047 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-08%20until%3A2015-09-09include%3Aretweets&src=typd
# 2015-09-08
# 1 tweets found, 1059 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-09%20until%3A2015-09-10include%3Aretweets&src=typd
# 2015-09-09
# 0 tweets found, 1060 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-10%20until%3A2015-09-11include%3Aretweets&src=typd
# 2015-09-10
# 0 tweets found, 1060 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-11%20until%3A2015-09-12include%3Aretweets&src=typd
# 2015-09-11
# 3 tweets found, 1060 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-12%20until%3A2015-09-13include%3Aretweets&src=typd
# 2015-09-12
# 1 tweets found, 1063 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-13%20until%3A2015-09-14include%3Aretweets&src=typd
# 2015-09-13
# 9 tweets found, 1064 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-14%20until%3A2015-09-15include%3Aretweets&src=typd
# 2015-09-14
# scrolling down to load more tweets
# 11 tweets found, 1073 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-15%20until%3A2015-09-16include%3Aretweets&src=typd
# 2015-09-15
# 0 tweets found, 1084 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-16%20until%3A2015-09-17include%3Aretweets&src=typd
# 2015-09-16
# 0 tweets found, 1084 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-17%20until%3A2015-09-18include%3Aretweets&src=typd
# 2015-09-17
# 1 tweets found, 1084 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-18%20until%3A2015-09-19include%3Aretweets&src=typd
# 2015-09-18
# 1 tweets found, 1085 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-19%20until%3A2015-09-20include%3Aretweets&src=typd
# 2015-09-19
# 3 tweets found, 1086 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-20%20until%3A2015-09-21include%3Aretweets&src=typd
# 2015-09-20
# 4 tweets found, 1089 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-21%20until%3A2015-09-22include%3Aretweets&src=typd
# 2015-09-21
# 1 tweets found, 1093 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-22%20until%3A2015-09-23include%3Aretweets&src=typd
# 2015-09-22
# 0 tweets found, 1094 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-23%20until%3A2015-09-24include%3Aretweets&src=typd
# 2015-09-23
# 1 tweets found, 1094 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-24%20until%3A2015-09-25include%3Aretweets&src=typd
# 2015-09-24
# 4 tweets found, 1095 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-25%20until%3A2015-09-26include%3Aretweets&src=typd
# 2015-09-25
# 5 tweets found, 1099 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-26%20until%3A2015-09-27include%3Aretweets&src=typd
# 2015-09-26
# 4 tweets found, 1104 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-27%20until%3A2015-09-28include%3Aretweets&src=typd
# 2015-09-27
# scrolling down to load more tweets
# 13 tweets found, 1108 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-28%20until%3A2015-09-29include%3Aretweets&src=typd
# 2015-09-28
# 7 tweets found, 1121 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-29%20until%3A2015-09-30include%3Aretweets&src=typd
# 2015-09-29
# 6 tweets found, 1128 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-09-30%20until%3A2015-10-01include%3Aretweets&src=typd
# 2015-09-30
# 2 tweets found, 1134 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-01%20until%3A2015-10-02include%3Aretweets&src=typd
# 2015-10-01
# scrolling down to load more tweets
# 16 tweets found, 1136 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-02%20until%3A2015-10-03include%3Aretweets&src=typd
# 2015-10-02
# 0 tweets found, 1152 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-03%20until%3A2015-10-04include%3Aretweets&src=typd
# 2015-10-03
# 4 tweets found, 1152 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-04%20until%3A2015-10-05include%3Aretweets&src=typd
# 2015-10-04
# 2 tweets found, 1156 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-05%20until%3A2015-10-06include%3Aretweets&src=typd
# 2015-10-05
# 4 tweets found, 1158 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-06%20until%3A2015-10-07include%3Aretweets&src=typd
# 2015-10-06
# 1 tweets found, 1162 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-07%20until%3A2015-10-08include%3Aretweets&src=typd
# 2015-10-07
# 2 tweets found, 1163 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-08%20until%3A2015-10-09include%3Aretweets&src=typd
# 2015-10-08
# 1 tweets found, 1165 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-09%20until%3A2015-10-10include%3Aretweets&src=typd
# 2015-10-09
# 3 tweets found, 1166 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-10%20until%3A2015-10-11include%3Aretweets&src=typd
# 2015-10-10
# 3 tweets found, 1169 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-11%20until%3A2015-10-12include%3Aretweets&src=typd
# 2015-10-11
# 3 tweets found, 1172 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-12%20until%3A2015-10-13include%3Aretweets&src=typd
# 2015-10-12
# 4 tweets found, 1175 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-13%20until%3A2015-10-14include%3Aretweets&src=typd
# 2015-10-13
# 3 tweets found, 1179 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-14%20until%3A2015-10-15include%3Aretweets&src=typd
# 2015-10-14
# 6 tweets found, 1182 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-15%20until%3A2015-10-16include%3Aretweets&src=typd
# 2015-10-15
# 1 tweets found, 1188 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-16%20until%3A2015-10-17include%3Aretweets&src=typd
# 2015-10-16
# 1 tweets found, 1189 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-17%20until%3A2015-10-18include%3Aretweets&src=typd
# 2015-10-17
# 3 tweets found, 1190 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-18%20until%3A2015-10-19include%3Aretweets&src=typd
# 2015-10-18
# 1 tweets found, 1193 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-19%20until%3A2015-10-20include%3Aretweets&src=typd
# 2015-10-19
# 1 tweets found, 1194 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-20%20until%3A2015-10-21include%3Aretweets&src=typd
# 2015-10-20
# scrolling down to load more tweets
# 14 tweets found, 1195 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-21%20until%3A2015-10-22include%3Aretweets&src=typd
# 2015-10-21
# 0 tweets found, 1209 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-22%20until%3A2015-10-23include%3Aretweets&src=typd
# 2015-10-22
# 0 tweets found, 1209 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-23%20until%3A2015-10-24include%3Aretweets&src=typd
# 2015-10-23
# 0 tweets found, 1209 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-24%20until%3A2015-10-25include%3Aretweets&src=typd
# 2015-10-24
# 1 tweets found, 1209 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-25%20until%3A2015-10-26include%3Aretweets&src=typd
# 2015-10-25
# 3 tweets found, 1210 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-26%20until%3A2015-10-27include%3Aretweets&src=typd
# 2015-10-26
# 4 tweets found, 1213 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-27%20until%3A2015-10-28include%3Aretweets&src=typd
# 2015-10-27
# 0 tweets found, 1217 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-28%20until%3A2015-10-29include%3Aretweets&src=typd
# 2015-10-28
# 2 tweets found, 1217 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-29%20until%3A2015-10-30include%3Aretweets&src=typd
# 2015-10-29
# scrolling down to load more tweets
# 15 tweets found, 1219 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-30%20until%3A2015-10-31include%3Aretweets&src=typd
# 2015-10-30
# 2 tweets found, 1234 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-10-31%20until%3A2015-11-01include%3Aretweets&src=typd
# 2015-10-31
# 3 tweets found, 1236 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-01%20until%3A2015-11-02include%3Aretweets&src=typd
# 2015-11-01
# scrolling down to load more tweets
# 11 tweets found, 1239 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-02%20until%3A2015-11-03include%3Aretweets&src=typd
# 2015-11-02
# 9 tweets found, 1250 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-03%20until%3A2015-11-04include%3Aretweets&src=typd
# 2015-11-03
# 5 tweets found, 1259 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-04%20until%3A2015-11-05include%3Aretweets&src=typd
# 2015-11-04
# 3 tweets found, 1264 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-05%20until%3A2015-11-06include%3Aretweets&src=typd
# 2015-11-05
# 6 tweets found, 1267 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-06%20until%3A2015-11-07include%3Aretweets&src=typd
# 2015-11-06
# 0 tweets found, 1273 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-07%20until%3A2015-11-08include%3Aretweets&src=typd
# 2015-11-07
# 1 tweets found, 1273 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-08%20until%3A2015-11-09include%3Aretweets&src=typd
# 2015-11-08
# scrolling down to load more tweets
# 18 tweets found, 1274 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-09%20until%3A2015-11-10include%3Aretweets&src=typd
# 2015-11-09
# 2 tweets found, 1292 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-10%20until%3A2015-11-11include%3Aretweets&src=typd
# 2015-11-10
# 0 tweets found, 1294 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-11%20until%3A2015-11-12include%3Aretweets&src=typd
# 2015-11-11
# 2 tweets found, 1294 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-12%20until%3A2015-11-13include%3Aretweets&src=typd
# 2015-11-12
# 0 tweets found, 1296 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-13%20until%3A2015-11-14include%3Aretweets&src=typd
# 2015-11-13
# 1 tweets found, 1296 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-14%20until%3A2015-11-15include%3Aretweets&src=typd
# 2015-11-14
# 4 tweets found, 1297 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-15%20until%3A2015-11-16include%3Aretweets&src=typd
# 2015-11-15
# 9 tweets found, 1301 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-16%20until%3A2015-11-17include%3Aretweets&src=typd
# 2015-11-16
# 1 tweets found, 1310 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-17%20until%3A2015-11-18include%3Aretweets&src=typd
# 2015-11-17
# 0 tweets found, 1311 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-18%20until%3A2015-11-19include%3Aretweets&src=typd
# 2015-11-18
# 0 tweets found, 1311 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-19%20until%3A2015-11-20include%3Aretweets&src=typd
# 2015-11-19
# 0 tweets found, 1311 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-20%20until%3A2015-11-21include%3Aretweets&src=typd
# 2015-11-20
# 1 tweets found, 1311 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-21%20until%3A2015-11-22include%3Aretweets&src=typd
# 2015-11-21
# 1 tweets found, 1312 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-22%20until%3A2015-11-23include%3Aretweets&src=typd
# 2015-11-22
# 1 tweets found, 1313 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-23%20until%3A2015-11-24include%3Aretweets&src=typd
# 2015-11-23
# 5 tweets found, 1314 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-24%20until%3A2015-11-25include%3Aretweets&src=typd
# 2015-11-24
# 0 tweets found, 1319 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-25%20until%3A2015-11-26include%3Aretweets&src=typd
# 2015-11-25
# 6 tweets found, 1319 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-26%20until%3A2015-11-27include%3Aretweets&src=typd
# 2015-11-26
# scrolling down to load more tweets
# 14 tweets found, 1325 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-27%20until%3A2015-11-28include%3Aretweets&src=typd
# 2015-11-27
# 1 tweets found, 1339 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-28%20until%3A2015-11-29include%3Aretweets&src=typd
# 2015-11-28
# 3 tweets found, 1340 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-29%20until%3A2015-11-30include%3Aretweets&src=typd
# 2015-11-29
# 3 tweets found, 1343 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-11-30%20until%3A2015-12-01include%3Aretweets&src=typd
# 2015-11-30
# 5 tweets found, 1346 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-12-01%20until%3A2015-12-02include%3Aretweets&src=typd
# 2015-12-01
# 0 tweets found, 1351 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-12-02%20until%3A2015-12-03include%3Aretweets&src=typd
# 2015-12-02
# scrolling down to load more tweets
# 12 tweets found, 1351 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-12-03%20until%3A2015-12-04include%3Aretweets&src=typd
# 2015-12-03
# scrolling down to load more tweets
# 13 tweets found, 1363 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-12-04%20until%3A2015-12-05include%3Aretweets&src=typd
# 2015-12-04
# 0 tweets found, 1376 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-12-05%20until%3A2015-12-06include%3Aretweets&src=typd
# 2015-12-05
# 2 tweets found, 1376 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2015-12-06%20until%3A2015-12-07include%3Aretweets&src=typd
# 2015-12-06
# 3 tweets found, 1378 total
# ...
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-01%20until%3A2018-12-02include%3Aretweets&src=typd
# 2018-12-01
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-02%20until%3A2018-12-03include%3Aretweets&src=typd
# 2018-12-02
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-03%20until%3A2018-12-04include%3Aretweets&src=typd
# 2018-12-03
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-04%20until%3A2018-12-05include%3Aretweets&src=typd
# 2018-12-04
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-05%20until%3A2018-12-06include%3Aretweets&src=typd
# 2018-12-05
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-06%20until%3A2018-12-07include%3Aretweets&src=typd
# 2018-12-06
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-07%20until%3A2018-12-08include%3Aretweets&src=typd
# 2018-12-07
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-08%20until%3A2018-12-09include%3Aretweets&src=typd
# 2018-12-08
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-09%20until%3A2018-12-10include%3Aretweets&src=typd
# 2018-12-09
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-10%20until%3A2018-12-11include%3Aretweets&src=typd
# 2018-12-10
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-11%20until%3A2018-12-12include%3Aretweets&src=typd
# 2018-12-11
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-12%20until%3A2018-12-13include%3Aretweets&src=typd
# 2018-12-12
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-13%20until%3A2018-12-14include%3Aretweets&src=typd
# 2018-12-13
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-14%20until%3A2018-12-15include%3Aretweets&src=typd
# 2018-12-14
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-15%20until%3A2018-12-16include%3Aretweets&src=typd
# 2018-12-15
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-16%20until%3A2018-12-17include%3Aretweets&src=typd
# 2018-12-16
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-17%20until%3A2018-12-18include%3Aretweets&src=typd
# 2018-12-17
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-18%20until%3A2018-12-19include%3Aretweets&src=typd
# 2018-12-18
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-19%20until%3A2018-12-20include%3Aretweets&src=typd
# 2018-12-19
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-20%20until%3A2018-12-21include%3Aretweets&src=typd
# 2018-12-20
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-21%20until%3A2018-12-22include%3Aretweets&src=typd
# 2018-12-21
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-22%20until%3A2018-12-23include%3Aretweets&src=typd
# 2018-12-22
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-23%20until%3A2018-12-24include%3Aretweets&src=typd
# 2018-12-23
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-24%20until%3A2018-12-25include%3Aretweets&src=typd
# 2018-12-24
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-25%20until%3A2018-12-26include%3Aretweets&src=typd
# 2018-12-25
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-26%20until%3A2018-12-27include%3Aretweets&src=typd
# 2018-12-26
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-27%20until%3A2018-12-28include%3Aretweets&src=typd
# 2018-12-27
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-28%20until%3A2018-12-29include%3Aretweets&src=typd
# 2018-12-28
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-29%20until%3A2018-12-30include%3Aretweets&src=typd
# 2018-12-29
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-30%20until%3A2018-12-31include%3Aretweets&src=typd
# 2018-12-30
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2018-12-31%20until%3A2019-01-01include%3Aretweets&src=typd
# 2018-12-31
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-01%20until%3A2019-01-02include%3Aretweets&src=typd
# 2019-01-01
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-02%20until%3A2019-01-03include%3Aretweets&src=typd
# 2019-01-02
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-03%20until%3A2019-01-04include%3Aretweets&src=typd
# 2019-01-03
# 0 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-04%20until%3A2019-01-05include%3Aretweets&src=typd
# 2019-01-04
# 1 tweets found, 2825 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-05%20until%3A2019-01-06include%3Aretweets&src=typd
# 2019-01-05
# 0 tweets found, 2826 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-06%20until%3A2019-01-07include%3Aretweets&src=typd
# 2019-01-06
# 0 tweets found, 2826 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-07%20until%3A2019-01-08include%3Aretweets&src=typd
# 2019-01-07
# 0 tweets found, 2826 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-08%20until%3A2019-01-09include%3Aretweets&src=typd
# 2019-01-08
# 0 tweets found, 2826 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-09%20until%3A2019-01-10include%3Aretweets&src=typd
# 2019-01-09
# 0 tweets found, 2826 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-10%20until%3A2019-01-11include%3Aretweets&src=typd
# 2019-01-10
# 1 tweets found, 2826 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-11%20until%3A2019-01-12include%3Aretweets&src=typd
# 2019-01-11
# 3 tweets found, 2827 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-12%20until%3A2019-01-13include%3Aretweets&src=typd
# 2019-01-12
# 0 tweets found, 2830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-13%20until%3A2019-01-14include%3Aretweets&src=typd
# 2019-01-13
# 0 tweets found, 2830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-14%20until%3A2019-01-15include%3Aretweets&src=typd
# 2019-01-14
# 0 tweets found, 2830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-15%20until%3A2019-01-16include%3Aretweets&src=typd
# 2019-01-15
# 0 tweets found, 2830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-16%20until%3A2019-01-17include%3Aretweets&src=typd
# 2019-01-16
# 0 tweets found, 2830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-17%20until%3A2019-01-18include%3Aretweets&src=typd
# 2019-01-17
# 0 tweets found, 2830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-18%20until%3A2019-01-19include%3Aretweets&src=typd
# 2019-01-18
# 0 tweets found, 2830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-19%20until%3A2019-01-20include%3Aretweets&src=typd
# 2019-01-19
# 0 tweets found, 2830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-20%20until%3A2019-01-21include%3Aretweets&src=typd
# 2019-01-20
# 0 tweets found, 2830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-21%20until%3A2019-01-22include%3Aretweets&src=typd
# 2019-01-21
# 0 tweets found, 2830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-22%20until%3A2019-01-23include%3Aretweets&src=typd
# 2019-01-22
# 0 tweets found, 2830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-23%20until%3A2019-01-24include%3Aretweets&src=typd
# 2019-01-23
# 3 tweets found, 2830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-24%20until%3A2019-01-25include%3Aretweets&src=typd
# 2019-01-24
# 0 tweets found, 2833 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-25%20until%3A2019-01-26include%3Aretweets&src=typd
# 2019-01-25
# 0 tweets found, 2833 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-26%20until%3A2019-01-27include%3Aretweets&src=typd
# 2019-01-26
# 2 tweets found, 2833 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-27%20until%3A2019-01-28include%3Aretweets&src=typd
# 2019-01-27
# 0 tweets found, 2835 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-28%20until%3A2019-01-29include%3Aretweets&src=typd
# 2019-01-28
# 2 tweets found, 2835 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-29%20until%3A2019-01-30include%3Aretweets&src=typd
# 2019-01-29
# 0 tweets found, 2837 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-30%20until%3A2019-01-31include%3Aretweets&src=typd
# 2019-01-30
# 2 tweets found, 2837 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-01-31%20until%3A2019-02-01include%3Aretweets&src=typd
# 2019-01-31
# 0 tweets found, 2839 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-01%20until%3A2019-02-02include%3Aretweets&src=typd
# 2019-02-01
# 1 tweets found, 2839 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-02%20until%3A2019-02-03include%3Aretweets&src=typd
# 2019-02-02
# 0 tweets found, 2840 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-03%20until%3A2019-02-04include%3Aretweets&src=typd
# 2019-02-03
# 1 tweets found, 2840 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-04%20until%3A2019-02-05include%3Aretweets&src=typd
# 2019-02-04
# 0 tweets found, 2841 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-05%20until%3A2019-02-06include%3Aretweets&src=typd
# 2019-02-05
# 0 tweets found, 2841 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-06%20until%3A2019-02-07include%3Aretweets&src=typd
# 2019-02-06
# 0 tweets found, 2841 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-07%20until%3A2019-02-08include%3Aretweets&src=typd
# 2019-02-07
# 1 tweets found, 2841 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-08%20until%3A2019-02-09include%3Aretweets&src=typd
# 2019-02-08
# 1 tweets found, 2842 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-09%20until%3A2019-02-10include%3Aretweets&src=typd
# 2019-02-09
# 0 tweets found, 2843 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-10%20until%3A2019-02-11include%3Aretweets&src=typd
# 2019-02-10
# 1 tweets found, 2843 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-11%20until%3A2019-02-12include%3Aretweets&src=typd
# 2019-02-11
# 2 tweets found, 2844 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-12%20until%3A2019-02-13include%3Aretweets&src=typd
# 2019-02-12
# 1 tweets found, 2846 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-13%20until%3A2019-02-14include%3Aretweets&src=typd
# 2019-02-13
# 1 tweets found, 2847 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-14%20until%3A2019-02-15include%3Aretweets&src=typd
# 2019-02-14
# 0 tweets found, 2848 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-15%20until%3A2019-02-16include%3Aretweets&src=typd
# 2019-02-15
# 0 tweets found, 2848 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-16%20until%3A2019-02-17include%3Aretweets&src=typd
# 2019-02-16
# 0 tweets found, 2848 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-17%20until%3A2019-02-18include%3Aretweets&src=typd
# 2019-02-17
# 0 tweets found, 2848 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-18%20until%3A2019-02-19include%3Aretweets&src=typd
# 2019-02-18
# 2 tweets found, 2848 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-19%20until%3A2019-02-20include%3Aretweets&src=typd
# 2019-02-19
# 3 tweets found, 2850 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-20%20until%3A2019-02-21include%3Aretweets&src=typd
# 2019-02-20
# 1 tweets found, 2853 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-21%20until%3A2019-02-22include%3Aretweets&src=typd
# 2019-02-21
# 2 tweets found, 2854 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-22%20until%3A2019-02-23include%3Aretweets&src=typd
# 2019-02-22
# 3 tweets found, 2856 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-23%20until%3A2019-02-24include%3Aretweets&src=typd
# 2019-02-23
# 4 tweets found, 2859 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-24%20until%3A2019-02-25include%3Aretweets&src=typd
# 2019-02-24
# 0 tweets found, 2863 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Agalhardothami%20since%3A2019-02-25%20until%3A2019-02-26include%3Aretweets&src=typd
# 2019-02-25
# 4 tweets found, 2863 total
# tweets found on this scrape:  2867
# total tweet count:  2867
# all done here

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from time import sleep
import json
import datetime

# edit these three variables
hashtag = '#Oscars'
start = datetime.datetime(2019, 2, 24)  # year, month, day
end = datetime.datetime(2019, 2, 25)  # year, month, day

# only edit these if you're having problems
delay = 1  # time to wait on each page load before reading the page
driver = webdriver.Chrome()  # options are Chrome() Firefox() Safari()

# don't mess with this stuff
twitter_ids_filename = 'all_ids_hashtag.json'
days = (end - start).days + 1
id_selector = '.time a.tweet-timestamp'
tweet_selector = 'li.js-stream-item'
user = user.lower()
ids = []

def format_day(date):
    day = '0' + str(date.day) if len(str(date.day)) == 1 else str(date.day)
    month = '0' + str(date.month) if len(str(date.month)) == 1 else str(date.month)
    year = str(date.year)
    return '-'.join([year, month, day])

def form_url(since, until):
    p1 = 'https://twitter.com/search?q='
    p2 =  hashtag + '%20since%3A' + since + '%20until%3A' + until + '&l=pt&src=typd'
    return p1 + p2

def increment_day(date, i):
    return date + datetime.timedelta(days=i)

for day in range(days):
    
    d1 = format_day(increment_day(start, 0))
    d2 = format_day(increment_day(start, 1))
    url = form_url(d1, d2)
    print(url)
    print(d1)
    driver.get(url)
    sleep(delay)

    try:
        found_tweets = driver.find_elements_by_css_selector(tweet_selector)
        increment = 10

        while len(found_tweets) >= increment:
            print('scrolling down to load more tweets')
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            sleep(delay)
            found_tweets = driver.find_elements_by_css_selector(tweet_selector)
            increment += 10

        print('{} tweets found, {} total'.format(len(found_tweets), len(ids)))

        for tweet in found_tweets:
            try:
                id = tweet.find_element_by_css_selector(id_selector).get_attribute('href').split('/')[-1]
                ids.append(id)
            except StaleElementReferenceException as e:
                print('lost element reference', tweet)

    except NoSuchElementException:
        print('no tweets on this day')

    start = increment_day(start, 1)

try:
    with open(twitter_ids_filename) as f:
        all_ids = ids + json.load(f)
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))

except FileNotFoundError:
    with open(twitter_ids_filename, 'w') as f:
        all_ids = ids
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))

with open(twitter_ids_filename, 'w') as outfile:
    json.dump(data_to_write, outfile)

print('all done here')
driver.close()
# Out:
# https://twitter.com/search?q=#Oscars%20since%3A2019-02-24%20until%3A2019-02-25&l=pt&src=typd
# 2019-02-24
# 0 tweets found, 0 total
# https://twitter.com/search?q=#Oscars%20since%3A2019-02-25%20until%3A2019-02-26&l=pt&src=typd
# 2019-02-25
# 0 tweets found, 0 total
# tweets found on this scrape:  0
# total tweet count:  0
# all done here
